# %% [markdown]
# <h1 style="font-size: 2.0em;">Mengakses sekelompok data dengan get_group()</h1>

# %% [markdown]
# <h1 style="font-size: 1.6em;">Import Modules</h1>

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# <h1 style="font-size: 1.6em;">Persiapan Data Frame</h1>

# %%
df = pd.read_csv('C:/Users/revania/Downloads/titanicfull.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# <h1 style="font-size: 1.6em;">Mengakses sekelompok data yang sudah terkelompok dengan get_group()</h1>

# %%
grouped_df = df.groupby('sex')

# %%
grouped_df.get_group('female').head(10)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 2        1         0                       Allison, Miss. Helen Loraine
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
#
#        sex   age  sibsp  parch    ticket      fare    cabin embarked
# 0   female  29.0      0      0     24160  211.3375       B5        S
# ...

# %%
grouped_df = df.groupby('survived')

# %%
grouped_df.get_group(1).head(10)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
#
#        sex    age  sibsp  parch    ticket      fare    cabin embarked
# 0   female  29.00      0      0     24160  211.3375       B5        S
# ...
